# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
from newsapi import NewsApiClient # pip install newsapi-python
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

load_dotenv('FinTech/Natural-Language-Processing/Keys.env')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hany_\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#
# Bad key savefig.frameon in file C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 421 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 472 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 473 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.3/matplotlibrc.template
# or from the matplotlib source distribution
# In C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hany_\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# True

# %%
# Read your api key environment variable
# YOUR CODE HERE!
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
# YOUR CODE HERE!
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles

# YOUR CODE HERE!
btc_headlines = newsapi.get_everything(q='bitcoin',  # q="btc", language="en", country="us"
                                    
                            
                                      language='en',
                                      sort_by='relevancy',
                                      )
btc_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 12720,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'https://www.engadget.com/about/editors/saqib-shah',
#    'title': 'El Salvador becomes the first country to approve Bitcoin as legal currency',
#    'description': 'El Salvador has voted to adopt Bitcoin as legal tender..',
#    'url': 'https://www.engadget.com/el-salvador-bitcoin-legal-tender-120440725.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-06/84c12d30-c919-11eb-a6ff-cedcc0c31aae',
#    'publishedAt': '2021-06-09T12:04:40Z',
#    'content': "El Salvador's President Nayib Bukele has made good on his promise to adopt Bitcoin as legal tender. Officials in the Central American country's congress voted to accept the cryptocurrency by a majori… [+1414 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'El Salvador Becomes First Country to Recognize Bitcoin as Currency',
#    'description': 'El Salvador has become the first country in the world to recognize the cryptocurrency bitcoin as legal currency, according to President Nayib Bukele in a tweet on Wednesday. Citizens will be able to pay taxes in bitcoin and, perhaps most importantly for bitco…',
#    'url': 'https://gizmodo.com/el-salvador-becomes-first-country-to-recognize-bitcoin-1847060384',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/afd5ae8b995bbe8ea734fe7ed1f746c4.jpg',
#    'publishedAt': '2021-06-09T10:00:00Z',
#    'content': 'El Salvador has become the first country in the world to recognize the cryptocurrency bitcoin as legal currency, according to President Nayib Bukele in a tweet on Wednesday. Citizens will be able to … [+3840 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Chaim Gartenberg',
#    'title': 'Coinbase is down amid massive cryptocurrency plunge',
#    'description': 'Cryptocurrency exchange Coinbase is experiencing a partial outage amid a massive plummet in cryptocurrencies (including Bitcoin, Etherium, and Dogecoin).',
#    'url': 'https://www.theverge.com/2021/5/19/22443701/coinbase-outage-bitcoin-ethereum-price-falling-cryptocurrency',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/9inLHdPYtMB1pyO936DAKt3d7b4=/0x215:3000x1786/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8954807/acastro_170726_1777_0008.jpg',
#    'publishedAt': '2021-05-19T13:47:36Z',
#    'content': 'Illustration by Alex Castro / The Verge\r\n\n \n\n Cryptocurrency exchange Coinbase is experiencing a “partial” outage this morning for its entire site and application. Additionally, both Coinbase and Bin… [+1307 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Gregory Barber',
#    'title': 'Elon Musk Tweets—and Crypto Markets Show Their Growing Pains',
#    'description': 'The Tesla and SpaceX billionaire has sent Dogecoin and Bitcoin on a roller coaster this month—and exposed weaknesses in the cryptocurrency market along the way.',
#    'url': 'https://www.wired.com/story/elon-musk-dogecoin-bitcoin-tweets-prices/',
#    'urlToImage': 'https://media.wired.com/photos/60a2ad2130981f87432bec20/191:100/w_1280,c_limit/business_elon-crypto_1232779339.jpg',
#    'publishedAt': '2021-05-17T23:27:59Z',
#    'content': 'Last week, whenElon Musk tweeted that he had spoken with the team of Doge developers about how to make the coin more efficient, the impact was predictable: It sent Dogecoin to the moon. It was just t… [+3313 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': 'Elon Musk says Tesla will resume Bitcoin purchases when Bitcoin gets greener',
#    'description': "It's all about clean energy, it seems.\xa0\nElon Musk and Tesla caused ripples in the cryptocurrency market in the past few months, first by announcing that Tesla had bought $1.5 billion worth of bitcoins and that it will start accepting Bitcoin for purchases, an…",
#    'url': 'https://mashable.com/article/tesla-bitcoin-purchases-green/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F06%252F14%252Fcc%252Faf6b974e89a64972a334f8675f5dc80a.36e5a.jpg%252F1200x630.jpg?signature=XiWTfhyod6_Xl2i4nyhER_1xCXQ=',
#    'publishedAt': '2021-06-14T07:15:49Z',
#    'content': "It's all about clean energy, it seems.\xa0\r\nElon Musk and Tesla caused ripples in the cryptocurrency market in the past few months, first by announcing that Tesla had bought $1.5 billion worth of bitcoi… [+2508 chars]"},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': 'Why Elon Musk has suddenly fallen out with Bitcoin',
#    'description': "That love affair between Elon Musk and Bitcoin? It's just become complicated.\xa0\nIt's been a rough couple of days in crypto world, with prices of most major crypto assets plummeting — Bitcoin, in particular, was trading at about $59,500 last Tuesday, only to dr…",
#    'url': 'https://mashable.com/article/elon-musk-bitcoin-complicated/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F05%252F17%252F6e%252F6bb2dd495d334580aa3eae31812e7b81.3039e.jpg%252F1200x630.jpg?signature=Isa1HKpfqBPSn06qogyytaEEA6M=',
#    'publishedAt': '2021-05-17T09:05:30Z',
#    'content': "That love affair between Elon Musk and Bitcoin? It's just become complicated.\xa0\r\nIt's been a rough couple of days in crypto world, with prices of most major crypto assets plummeting Bitcoin, in partic… [+6347 chars]"},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Lucas Matney',
#    'title': 'Bitcoin crashes as investors fear crypto bull market could be nearing its end',
#    'description': 'Bitcoin, Ethereum and a host of Altcoins suffered massive drops Tuesday night and Wednesday morning, erasing months of gains and hundreds of billions in market cap. The overall crypto market shrunk more than 20% over the past 24 hours according to crypto trac…',
#    'url': 'http://techcrunch.com/2021/05/19/bitcoin-crashes-as-investors-fear-crypto-bull-market-could-be-nearing-its-end/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2016/02/shutterstock_121576933.jpg?w=711',
#    'publishedAt': '2021-05-19T16:05:22Z',
#    'content': 'Bitcoin, Ethereum and a host of Altcoins suffered massive drops Tuesday night and Wednesday morning, erasing months of gains and hundreds of billions in market cap. The overall crypto market shrunk m… [+1182 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'https://www.engadget.com/about/editors/jon-fingas',
#    'title': 'Coinbase struggles with outages during cryptocurrency volatility',
#    'description': 'Coinbase is reeling from outages as a massive cryptocurrency selloff takes place..',
#    'url': 'https://www.engadget.com/coinbase-outage-amid-cryptocurrency-price-drop-150658356.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-05/1f540640-b8af-11eb-9fbf-39d423ba27ac',
#    'publishedAt': '2021-05-19T15:06:58Z',
#    'content': "Now isn't the greatest time to be a cryptocurrency trader. Coinbase suffered an hours-long outage this morning (May 19th) that hindered transactions on the exchange. The company had pinpointed the ma… [+909 chars]"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Bitcoin: El Salvador makes cryptocurrency legal tender',
#    'description': 'It is the first country in the world to make the move, following a proposal by its president.',
#    'url': 'https://www.bbc.co.uk/news/world-latin-america-57398274',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/AB75/production/_118839834_bitcoinstorereuters.jpg',
#    'publishedAt': '2021-06-09T08:27:58Z',
#    'content': 'image captionThe move means bitcoin will be accepted everywhere for goods and services, alongside the US dollar\r\nEl Salvador has become the first country in the world to officially classify Bitcoin a… [+2233 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Alyse Stanley',
#    'title': "Miami's Bitcoin Conference May Be the Latest Covid-19 Super Spreader Event",
#    'description': 'Several crypto fans that descended on Miami, Florida, last weekend for the largest bitcoin conference in history are now saying they’ve tested positive for covid-19. Read more...',
#    'url': 'https://gizmodo.com/miamis-bitcoin-conference-may-be-the-latest-covid-19-su-1847076668',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/c23c71ae398aed2dc168878db3bce496.jpg',
#    'publishedAt': '2021-06-11T00:45:00Z',
#    'content': 'Several crypto fans that descended on Miami, Florida, last weekend for the largest bitcoin conference in history are now saying theyve tested positive for covid-19. \r\nLarry Cermak, research director … [+2389 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Lucas Matney',
#    'title': 'In search of a new crypto deity',
#    'description': 'Hello friends, and welcome back to Week in Review! Last week, I wrote about tech taking on Disney. This week, I’m talking about the search for a new crypto messiah. If you’re reading this on the TechCrunch site, you can get this in your inbox from the newslet…',
#    'url': 'http://techcrunch.com/2021/06/05/in-search-of-a-new-crypto-deity/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/02/GettyImages-921871490.jpg?w=600',
#    'publishedAt': '2021-06-05T19:20:23Z',
#    'content': 'Hello friends, and welcome back to Week in Review!\r\nLast week, I wrote about tech taking on Disney. This week, I’m talking about the search for a new crypto messiah.\r\nIf youre reading this on the Tec… [+7741 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Shoshana Wodinsky',
#    'title': 'PayPal Will Let Users Transfer Bitcoin to Third-Party Wallets',
#    'description': 'In spite of the environmental and regulatory ills that generally come with crypto as a currency, PayPal’s bitcoin ambitions keep on ramping up. On Wednesday, Jose Fernandez da Ponte—the company’s VP of all things blockchain—confirmed in an interview that PayP…',
#    'url': 'https://gizmodo.com/paypal-will-let-users-transfer-bitcoin-to-third-party-w-1846982029',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/4457df9370749ae7882e139b3d47e571.jpg',
#    'publishedAt': '2021-05-27T16:25:00Z',
#    'content': 'In spite of the environmental and regulatory ills that generally come with crypto as a currency, PayPals bitcoin ambitions keep on ramping up. On Wednesday, Jose Fernandez da Pontethe companys VP of … [+2193 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "Donald Trump calls Bitcoin 'a scam against the dollar'",
#    'description': 'The controversial former US president thinks the cryptocurrency is a threat to the US dollar.',
#    'url': 'https://www.bbc.co.uk/news/business-57392734',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/BA93/production/_118836774_trump1.jpg',
#    'publishedAt': '2021-06-08T01:12:59Z',
#    'content': 'By Mary-Ann RussonBusiness reporter, BBC News\r\nimage copyrightGetty Images\r\nFormer US President Donald Trump has told Fox Business that he sees Bitcoin as a "scam" affecting the value of the US dolla… [+3638 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Mitchell Clark',
#    'title': 'Iran bans cryptocurrency mining for four months to stave off blackouts',
#    'description': 'As blackouts affect some of Iran’s major cities, the country is banning cryptocurrency mining and going after unlicensed operations. The blackouts have been blamed on a drought affecting hydroelectric generation.',
#    'url': 'https://www.theverge.com/2021/5/26/22455264/iran-cryptocurrency-mining-ban-annual-summer-bitcoin-spies',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/I_plGlE5qd5Sl2uU9Luh1kQ4XYg=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/10432805/mdoying_180308_2373_0092still.jpg',
#    'publishedAt': '2021-05-26T20:34:57Z',
#    'content': 'The ban affects licensed and unlicensed miners alike\r\nPhoto by Michele Doying / The Verge\r\nIran is temporarily banning cryptocurrency mining after some of the countrys major cities experienced repeat… [+2224 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Lucas Matney',
#    'title': 'Elon Musk giveth and taketh away',
#    'description': 'Hello friends, and welcome back to Week in Review! Last week, I wrote about Facebook’s never-ending Trump problem. This week, I’m looking at Elon Musk’s wild week of whipping crypto markets. If you’re reading this on the TechCrunch site, you can get this in y…',
#    'url': 'http://techcrunch.com/2021/05/16/elon-musk-giveth-and-taketh-away/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2018/04/infinitywar5aa86b6fc55c4-2.jpg?w=758',
#    'publishedAt': '2021-05-16T21:12:04Z',
#    'content': 'Hello friends, and welcome back to Week in Review!\r\nLast week, I wrote about Facebook’s never-ending Trump problem. This week, I’m looking at Elon Musk’s wild week of whipping crypto markets.\r\nIf you… [+5768 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jess Joho',
#    'title': 'PayPal will soon let you exchange Bitcoin across third-party apps',
#    'description': 'After years of hesitation, PayPal continues to double down on cryptocurrency.\nSoon, PayPal users in the U.S. will be able to transfer, withdraw, and exchange their crypto (like Bitcoin) across popular third-party platforms and digital wallets like Coinbase, t…',
#    'url': 'https://mashable.com/article/paypal-bitcoin-coinbase-third-party-wallets/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F05%252F27%252F04%252F76459f233c4841ddb6eb1fd9e17d1588.955a7.jpg%252F1200x630.jpg?signature=MPDFygq0VAdNWmKrLwSEYzxSI9E=',
#    'publishedAt': '2021-05-27T19:25:47Z',
#    'content': 'After years of hesitation, PayPal continues to double down on cryptocurrency.\r\nSoon, PayPal users in the U.S. will be able to transfer, withdraw, and exchange their crypto (like Bitcoin) across popul… [+2947 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'ilee@insider.com (Isabelle Lee)',
#    'title': 'Bitcoin-exposed stocks slide alongside the cryptocurrency as Elon Musk once again wreaks havoc with a tweet',
#    'description': 'Shares of bitcoin-exposed companies suffered in tandem with bitcoin as tweets from the Tesla CEO continue to move markets.',
#    'url': 'https://www.businessinsider.com/microstrategy-coinbase-square-bitcoin-stock-price-reaction-elon-musk-tweet-2021-5',
#    'urlToImage': 'https://i.insider.com/60747c683e3fe7001882a243?width=1200&format=jpeg',
#    'publishedAt': '2021-05-17T14:06:39Z',
#    'content': 'Companies exposed to bitcoin slid on Monday in the wake of the cryptocurrency plunging to its lowest level since February after Elon Musk suggested Tesla might have sold its holdings over the weekend… [+1120 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Capital Calls: Bitcoin salaries - Reuters',
#    'description': 'Capital Calls: Bitcoin salaries\xa0\xa0Reuters',
#    'url': 'https://www.reuters.com/breakingviews/capital-calls-bitcoin-salaries-2021-05-21/',
#    'urlToImage': None,
#    'publishedAt': '2021-05-21T16:11:00Z',
#    'content': "Concise insights on global finance.\r\n-----------------------------------------------\r\nANOTHER DAY, ANOTHER CRYPTO. It's still rare but some people are paid in bitcoin, including a few U.S. athletes. … [+1795 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Bitcoin takes a wild ride on Musk tweets - Reuters',
#    'description': "Bitcoin rallied from three-month low on Monday in a volatile session that saw investors initially selling and then buying cryptocurrencies in the wake of Tesla boss Elon Musk's tweets about the carmaker's bitcoin holdings. Emer McCarthy reports.",
#    'url': 'https://www.reuters.com/video/watch/idOVEDCUHL7',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20210517&i=OVEDCUHL7&r=OVEDCUHL7&t=2',
#    'publishedAt': '2021-05-17T09:58:50Z',
#    'content': "Posted \r\nBitcoin rallied from three-month low on Monday in a volatile session that saw investors initially selling and then buying cryptocurrencies in the wake of Tesla boss Elon Musk's tweets about … [+54 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin hits three-month low as Musk drives investors to exit - Reuters',
#    'description': "Bitcoin dropped to a three-month low on Monday as investors sold cryptocurrencies in the wake of Tesla boss Elon Musk's hinting over the weekend that the carmarker is considering or may have already sold some of its bitcoin holdings.",
#    'url': 'https://www.reuters.com/article/us-crypto-currency-idUSKCN2CY0AC',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210517&t=2&i=1562347267&r=LYNXNPEH4G04H&w=800',
#    'publishedAt': '2021-05-17T04:31:00Z',
#    'content': 'By Reuters Staff\r\nSINGAPORE (Reuters) - Bitcoin dropped to a three-month low on Monday as investors sold cryptocurrencies in the wake of Tesla boss Elon Musks hinting over the weekend that the carmar… [+2377 chars]'}]}

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
eth_headlines = newsapi.get_everything(q='ethereum',  # q="eth", language="en", country="us"
                                    
                            
                                      language='en',
                                      sort_by='relevancy',
                                      )
eth_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 3820,
#  'articles': [{'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Joseph Green',
#    'title': 'This blockchain development course bundle is on sale for 97% off',
#    'description': 'TL;DR: The Cryptocurrency with Ethereum and Solidity Blockchain Developer Bundle is on sale for £21.25 as of June 17, saving you 97% on list price.\n\nIs everyone you know investing in cryptocurrency? The Cryptocurrency with Ethereum and Solidity Blockchain Dev…',
#    'url': 'https://mashable.com/uk/shopping/june-17-cryptocurrency-ethereum-and-solidity-blockchain-developer-bundle/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F06%252F17%252Fa4%252Fd95c8d39ee014266beea8c6b9d053d19.1c765.jpg%252F1200x630.jpg?signature=13rMcdTv3FsupfDx5m8coAhsN-4=',
#    'publishedAt': '2021-06-17T04:05:00Z',
#    'content': 'TL;DR: The Cryptocurrency with Ethereum and Solidity Blockchain Developer Bundle is on sale for £21.25 as of June 17, saving you 97% on list price.\r\nIs everyone you know investing in cryptocurrency? … [+949 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Lucas Matney',
#    'title': 'Bitcoin crashes as investors fear crypto bull market could be nearing its end',
#    'description': 'Bitcoin, Ethereum and a host of Altcoins suffered massive drops Tuesday night and Wednesday morning, erasing months of gains and hundreds of billions in market cap. The overall crypto market shrunk more than 20% over the past 24 hours according to crypto trac…',
#    'url': 'http://techcrunch.com/2021/05/19/bitcoin-crashes-as-investors-fear-crypto-bull-market-could-be-nearing-its-end/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2016/02/shutterstock_121576933.jpg?w=711',
#    'publishedAt': '2021-05-19T16:05:22Z',
#    'content': 'Bitcoin, Ethereum and a host of Altcoins suffered massive drops Tuesday night and Wednesday morning, erasing months of gains and hundreds of billions in market cap. The overall crypto market shrunk m… [+1182 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': "Ethereum's 27-year-old founder says we're in a crypto bubble. Did it just burst?",
#    'description': 'Vitalik Buterin is the 27-year-old co-founder of the world\'s second largest cryptocurrency, Ethereum. He talks bubbles, Elon Musk, and "screwing the big guy" with CNN Business\' Matt Egan.',
#    'url': 'https://www.cnn.com/videos/business/2021/05/19/crypto-ethereum-vitalik-buterin-elon-musk-bubble-orig.cnn-business',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210518150319-01-vitalik-buterin-file-super-tease.jpg',
#    'publishedAt': '2021-05-20T11:02:42Z',
#    'content': ''},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern UK technology editor',
#    'title': 'Ethereum cryptocurrency to slash carbon emissions',
#    'description': 'Project says it is months away from new infrastructure model that would use a hundredth of the energyEthereum, the second largest cryptocurrency after bitcoin, is just “months” away from shifting its underlying infrastructure to a new model that would slash i…',
#    'url': 'https://amp.theguardian.com/technology/2021/may/19/ethereum-cryptocurrency-to-slash-carbon-emissions',
#    'urlToImage': 'https://i.guim.co.uk/img/media/6ede0dd81c7b8105d991cfeaaf6647c3210cc369/0_0_6220_3732/master/6220.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=6426bc0680efbf75290eb460f1da7809',
#    'publishedAt': '2021-05-19T13:00:16Z',
#    'content': 'Ethereum, the second largest cryptocurrency after bitcoin, is just months away from shifting its underlying infrastructure to a new model that would slash its carbon emissions a hundredfold, the proj… [+3301 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Ethereum extends gains to rise 8%; bitcoin firms - Reuters',
#    'description': 'Cryptocurrency Ethereum extended gains to rise more than 8% on Monday to $2,587 but remained 40% below a record high of above $4,300 hit earlier this month.',
#    'url': 'https://www.reuters.com/technology/ethereum-rises-5-2509-bitcoin-firm-2021-05-31/',
#    'urlToImage': 'https://www.reuters.com/resizer/yeaYVdBQ4_EGCbJU5Z5E6qExbDw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/VMU2AOPUXRPU7KWLBR6GOWQHCM.jpg',
#    'publishedAt': '2021-05-31T12:17:00Z',
#    'content': 'A representation of virtual currency Ethereum is seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/Illustration/File PhotoCryptocurrency Ethereum extende… [+1099 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'https://www.engadget.com/about/editors/saqib-shah',
#    'title': 'Most new NVIDIA RTX gaming GPUs will be crypto-limited',
#    'description': 'NVIDIA is extending its limits on GPU capacity to more GeForce RTX 30-series cards in a bid to limit the shortages caused by cryptomining..',
#    'url': 'https://www.engadget.com/nvidia-rtx-gpu-crypto-limit-122007238.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-05/9623e120-b88f-11eb-97fe-3e54cb87f3ca',
#    'publishedAt': '2021-05-19T12:20:07Z',
#    'content': "GPU shortages and inflated prices have become a byproduct of the growth of cryptomining. Needless to say, that's bad news for the gamers that make up a big chunk of the computing industry's customer … [+1461 chars]"},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Chaim Gartenberg',
#    'title': 'Coinbase is down amid massive cryptocurrency plunge',
#    'description': 'Cryptocurrency exchange Coinbase is experiencing a partial outage amid a massive plummet in cryptocurrencies (including Bitcoin, Etherium, and Dogecoin).',
#    'url': 'https://www.theverge.com/2021/5/19/22443701/coinbase-outage-bitcoin-ethereum-price-falling-cryptocurrency',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/9inLHdPYtMB1pyO936DAKt3d7b4=/0x215:3000x1786/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8954807/acastro_170726_1777_0008.jpg',
#    'publishedAt': '2021-05-19T13:47:36Z',
#    'content': 'Illustration by Alex Castro / The Verge\r\n\n \n\n Cryptocurrency exchange Coinbase is experiencing a “partial” outage this morning for its entire site and application. Additionally, both Coinbase and Bin… [+1307 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'Ethereum creator Vitalik Buterin made more than $ 4 million from Dogecoin thanks to Elon Musk',
#    'description': 'Ethereum billionaire founder Vitalik Buterin bet $ 25,000 on the cryptocurrency meme Dogecoin and came out winning.',
#    'url': 'https://www.entrepreneur.com/article/374264',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1623352319-Jun10VitaliButerincreadordeEthereumgan4millonesdedlaresDogecoinPORT.jpg',
#    'publishedAt': '2021-06-10T19:12:00Z',
#    'content': 'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nLast May, VitaliK Buterin became the youngest billionaire in the world at just 27 ye… [+2422 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Ethereum Staking Will Drop Power Consumption By 99%',
#    'description': "After Ethereum transitions to proof-of-stake, the blockchain's power consumption is expected to drop by more than 99%, making it about 7,000 times more energy efficient than Bitcoin. Crypto Briefing reports: Ethereum will reduce its energy consumption by 99.9…",
#    'url': 'https://hardware.slashdot.org/story/21/05/18/2242212/ethereum-staking-will-drop-power-consumption-by-99',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2021-05-19T01:25:00Z',
#    'content': 'Ethereum will reduce its energy consumption by 99.95% following its transition to proof-of-stake, according to a new blog post from Carl Beekhuizen of the Ethereum Foundation. Beekhuizen estimated th… [+738 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Norton 360 Antivirus Now Lets You Mine Ethereum Cryptocurrency',
#    'description': 'NortonLifelock has added the ability to mine Ethereum cryptocurrency directly within its Norton 360 antivirus program as a way to "protect" users from malicious mining software. BleepingComputer reports: This new mining feature is called \'Norton Crypto\' and w…',
#    'url': 'https://slashdot.org/story/21/06/03/0358213/norton-360-antivirus-now-lets-you-mine-ethereum-cryptocurrency',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2021-06-03T10:00:00Z',
#    'content': "This new mining feature is called 'Norton Crypto' and will be rolling out tomorrow to Norton 360 users enrolled in Norton's early adopter program. When Norton Crypto is enabled, the software will use… [+631 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'GameStop Is Building An NFT Platform On Ethereum',
#    'description': 'GameStop has quietly unveiled a new web portal for a non-fungible token (NFT) platform. The Block reports: "We are building a team" the page declares, stating: "We welcome exceptional engineers (solidity, react, python), designers, gamers, marketers, and comm…',
#    'url': 'https://slashdot.org/story/21/05/26/2127252/gamestop-is-building-an-nft-platform-on-ethereum',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2021-05-27T00:45:00Z',
#    'content': '"We are building a team" the page declares, stating: "We welcome exceptional engineers (solidity, react, python), designers, gamers, marketers, and community leaders. If you want to join our team, se… [+478 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-dreyfuss',
#    'title': 'Bitcoin posts record weekly outflows as gains stall -CoinShares data - Reuters',
#    'description': 'Bitcoin hit record outflows last week, as investors diversified into cryptocurrency assets with new developments in their specific network such as ethereum, data from digital currency manager CoinShares showed on Monday.',
#    'url': 'https://www.reuters.com/technology/bitcoin-posts-record-weekly-outflows-gains-stall-coinshares-data-2021-05-17/',
#    'urlToImage': 'https://www.reuters.com/resizer/GafqaGUHopRoftkCaNrKtqC9l78=/1200x628/smart/cloudfront-us-east-2.images.arcpublishing.com/reuters/6SPYSVV3PRO3LAIGU6UBJP43AE.jpg',
#    'publishedAt': '2021-05-17T21:56:00Z',
#    'content': 'Representations of virtual currency Bitcoin are placed on U.S. Dollar banknotes in this illustration taken May 26, 2020. REUTERS/Dado Ruvic/File PhotoBitcoin hit record outflows last week, as investo… [+2052 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters',
#    'title': 'Bitcoin, ethereum plunge; crypto market cap losses nearly $1 trillion - Reuters',
#    'description': 'Bitcoin and ethereum posted their largest one-day drop since March last year on Wednesday, with losses in the market capitalization for the entire cryptocurrency sector approaching $1 trillion.',
#    'url': 'https://www.reuters.com/technology/bitcoin-ethereum-plunge-crypto-market-cap-losses-nearly-1-trillion-2021-05-19/',
#    'urlToImage': None,
#    'publishedAt': '2021-05-19T13:47:00Z',
#    'content': 'Bitcoin and ethereum posted their largest one-day drop since March last year on Wednesday, with losses in the market capitalization for the entire cryptocurrency sector approaching $1 trillion.\r\nThe … [+523 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Charles-Henry Monchau',
#    'title': 'SafeMoon: New Dogecoin or Ponzi scheme?',
#    'description': 'A new cryptocurrency is getting ready for a shot at the moon like Dogecoin, Bitcoin and Ethereum. But is it really primed for prominent success?',
#    'url': 'https://www.entrepreneur.com/article/372691',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1622046837-GettyImages-1318956100.jpg',
#    'publishedAt': '2021-05-31T15:00:00Z',
#    'content': 'Opinions expressed by Entrepreneur contributors are their own.\r\nLaunched in March 2021 and having racked up more than one million users already, SafeMoon is a blockchain-based cryptocurrency\xa0similar … [+3939 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Whitney Kimball',
#    'title': '8 Money Toilets',
#    'description': 'A ferocious bidding war over a misshapen chicken nugget concluded at $99,997 in the wee hours of Friday morning. Doesn’t seem weird at all, in a world where people are spending millions of dollars for blockchain tokens backed only by words. But wait, is this …',
#    'url': 'https://gizmodo.com/8-money-toilets-1847036893',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/a528d73090abd2c91b536585aa942f8b.jpg',
#    'publishedAt': '2021-06-04T22:20:00Z',
#    'content': 'CryptoPunks represent the only historically relevant narrative upon which value could conceivably live for decades within an expanding catalogue raisonné, and Ill be damned if Im counting Jacks tweet… [+1096 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Buying a pink NFT cat was a crypto nightmare',
#    'description': 'Trying to own a virtual feline proves to be an exhausting and expensive process.',
#    'url': 'https://www.bbc.co.uk/news/technology-57273904',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/288B/production/_118697301_kimcatdardshian_eth.png',
#    'publishedAt': '2021-05-29T23:05:42Z',
#    'content': "By Cristina CriddleTechnology reporter\r\nimage captionNFT Kim Catdarshian's fur is dotted with diamonds, the symbol for cryptocurrency Ethereum\r\nThe hype surrounding NFTs (non-fungible tokens) has bee… [+6387 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'The billionaire creator of Ethereum already expected the collapse of cryptocurrencies',
#    'description': "At 27 years old, Vitalik Buterin became the billionaire thanks to his creation: the cryptocurrency Ethereum. But he is aware that the bubble will burst at any moment, if it hasn't already.",
#    'url': 'https://www.entrepreneur.com/article/372641',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1621628581-May21VitalikButerinbillonariocreadorEthereumcolapsocriptomonedasPORT.jpg',
#    'publishedAt': '2021-05-21T20:38:00Z',
#    'content': 'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nThis week, the world of cryptocurrencies experienced a severe collapse, losing about… [+2059 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Kari McMahon',
#    'title': "Two ether bulls break down 3 reasons why solana is an existential threat to ethereum in a 'winner takes most' market where some of today's most popular crypto networks won't survive",
#    'description': 'Summary List PlacementIn March 2020, blockchain protocol solana officially launched as an alternative for businesses and developers that want to launch decentralized products of massive scale.\xa0\nSince launching, the solana token (SOL) has become one of the top…',
#    'url': 'https://www.businessinsider.com/crypto-investing-trading-bull-case-solana-sol-eth-ethereum-investors-2021-5',
#    'urlToImage': 'https://i.insider.com/5de2888bfd9db2191162da13?width=1200&format=jpeg',
#    'publishedAt': '2021-05-28T09:30:00Z',
#    'content': 'In March 2020, blockchain protocol solana officially launched as an alternative for businesses and developers that want to launch decentralized products of massive scale.\xa0\r\nSince launching, the solan… [+6750 chars]'},
#   {'source': {'id': None, 'name': 'BNNBloomberg.ca'},
#    'author': 'Bloomberg News',
#    'title': 'Ethereum closes in on long-sought fix to cut energy use over 99% - BNN',
#    'description': 'Users and developers of the world’s most-used blockchain have been wrangling with its carbon-footprint problem for as long as it’s been around. Now, they say, several recent breakthroughs will finally enable them to drastically cut energy use in a year or les…',
#    'url': 'http://www.bnnbloomberg.ca/ethereum-closes-in-on-long-sought-fix-to-cut-energy-use-over-99-1.1607612',
#    'urlToImage': 'http://www.bnnbloomberg.ca/polopoly_fs/1.1607613!/fileimage/httpImage/image.jpg_gen/derivatives/landscape_620/vitalik-buterin-co-founder-of-ethereum-foundation-and-bitcoin-magazine-speaks-during-the-techcrunch-disrupt-2017-in-san-francisco-california-u-s-on-monday-sept-18-2017-techcrunch-disrupt-the-world-s-leading-authority-in-debuting-revolutionary-startups-gathers-the-brightest-entrepreneurs-investors-hackers-and-tech-fans-for-on-stage-interviews-photographer-david-paul-morris-bloomberg.jpg',
#    'publishedAt': '2021-05-23T14:02:25Z',
#    'content': 'Users and developers of the worlds most-used blockchain have been wrangling with its carbon-footprint problem for as long as its been around. Now, they say, several recent breakthroughs will finally … [+6497 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': 'Inventor of the World Wide Web is auctioning its original source code as an NFT',
#    'description': "Sir Tim Berners-Lee, credited as the inventor of the World Wide Web, is selling the source code for his invention as an NFT at a Sotheby's auction.\xa0\nThe NFT, or non-fungible token, is a type of cryptocurrency that resides on a smart contract platform, typical…",
#    'url': 'https://mashable.com/article/tim-berners-lee-www-nft/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F06%252F15%252Fd5%252F82216b947335489684a419c1494c67cb.396e6.jpg%252F1200x630.jpg?signature=uv7urUIz6Zay5TmHDV5vXIgpWO4=',
#    'publishedAt': '2021-06-15T13:17:32Z',
#    'content': "Sir Tim Berners-Lee, credited as the inventor of the World Wide Web, is selling the source code for his invention as an NFT at a Sotheby's auction.\xa0\r\nThe NFT, or non-fungible token, is a type of cryp… [+2698 chars]"}]}

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
btc_sentiment_df = pd.DataFrame.from_dict(btc_headlines["articles"])

btc_sentiment_df.head()
# Out:
#                                               author  \
# 0  https://www.engadget.com/about/editors/saqib-shah
# 1                                         Matt Novak
# 2                                   Chaim Gartenberg
# 3                                     Gregory Barber
# 4                                     Stan Schroeder
#
#                                              content  \
# 0  El Salvador's President Nayib Bukele has made ...
# 1  El Salvador has become the first country in th...
# 2  Illustration by Alex Castro / The Verge\r\n\n ...
# 3  Last week, whenElon Musk tweeted that he had s...
# 4  It's all about clean energy, it seems. \r\nElo...
#
#                                          description           publishedAt  \
# 0  El Salvador has voted to adopt Bitcoin as lega...  2021-06-09T12:04:40Z
# 1  El Salvador has become the first country in th...  2021-06-09T10:00:00Z
# 2  Cryptocurrency exchange Coinbase is experienci...  2021-05-19T13:47:36Z
# 3  The Tesla and SpaceX billionaire has sent Doge...  2021-05-17T23:27:59Z
# 4  It's all about clean energy, it seems. \nElon ...  2021-06-14T07:15:49Z
#
#                                      source  \
# 0    {'id': 'engadget', 'name': 'Engadget'}
# 1       {'id': None, 'name': 'Gizmodo.com'}
# 2  {'id': 'the-verge', 'name': 'The Verge'}
# 3          {'id': 'wired', 'name': 'Wired'}
# 4    {'id': 'mashable', 'name': 'Mashable'}
#
#                                                title  \
# 0  El Salvador becomes the first country to appro...
# 1  El Salvador Becomes First Country to Recognize...
# 2  Coinbase is down amid massive cryptocurrency p...
# 3  Elon Musk Tweets—and Crypto Markets Show Their...
# 4  Elon Musk says Tesla will resume Bitcoin purch...
#
#                                                  url  \
# 0  https://www.engadget.com/el-salvador-bitcoin-l...
# 1  https://gizmodo.com/el-salvador-becomes-first-...
# 2  https://www.theverge.com/2021/5/19/22443701/co...
# 3  https://www.wired.com/story/elon-musk-dogecoin...
# 4  https://mashable.com/article/tesla-bitcoin-pur...
#
#                                           urlToImage
# 0  https://s.yimg.com/os/creatr-uploaded-images/2...
# 1  https://i.kinja-img.com/gawker-media/image/upl...
# 2  https://cdn.vox-cdn.com/thumbor/9inLHdPYtMB1py...
# 3  https://media.wired.com/photos/60a2ad2130981f8...
# 4  https://mondrian.mashable.com/2021%252F06%252F...

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
eth_sentiment_df = pd.DataFrame.from_dict(eth_headlines["articles"])

eth_sentiment_df.head()
# Out:
#                                               author  \
# 0                                      Connie Loizos
# 1                                       Lucas Matney
# 2                                               None
# 3                                            Reuters
# 4  https://www.engadget.com/about/editors/saqib-shah
#
#                                              content  \
# 0  Solana isn’t known yet outside of the crypto c...
# 1  Bitcoin, Ethereum and a host of Altcoins suffe...
# 2
# 3  A representation of virtual currency Ethereum ...
# 4  GPU shortages and inflated prices have become ...
#
#                                          description           publishedAt  \
# 0  Solana isn’t known yet outside of the crypto c...  2021-05-15T01:49:36Z
# 1  Bitcoin, Ethereum and a host of Altcoins suffe...  2021-05-19T16:05:22Z
# 2  Vitalik Buterin is the 27-year-old co-founder ...  2021-05-20T11:02:42Z
# 3  Cryptocurrency Ethereum extended gains to rise...  2021-05-31T12:17:00Z
# 4  NVIDIA is extending its limits on GPU capacity...  2021-05-19T12:20:07Z
#
#                                        source  \
# 0  {'id': 'techcrunch', 'name': 'TechCrunch'}
# 1  {'id': 'techcrunch', 'name': 'TechCrunch'}
# 2                {'id': 'cnn', 'name': 'CNN'}
# 3        {'id': 'reuters', 'name': 'Reuters'}
# 4      {'id': 'engadget', 'name': 'Engadget'}
#
#                                                title  \
# 0  Solana, a blockchain platform followed by top ...
# 1  Bitcoin crashes as investors fear crypto bull ...
# 2  Ethereum's 27-year-old founder says we're in a...
# 3  Ethereum extends gains to rise 8%; bitcoin fir...
# 4  Most new NVIDIA RTX gaming GPUs will be crypto...
#
#                                                  url  \
# 0  http://techcrunch.com/2021/05/14/solana-a-bloc...
# 1  http://techcrunch.com/2021/05/19/bitcoin-crash...
# 2  https://www.cnn.com/videos/business/2021/05/19...
# 3  https://www.reuters.com/technology/ethereum-ri...
# 4  https://www.engadget.com/nvidia-rtx-gpu-crypto...
#
#                                           urlToImage
# 0  https://techcrunch.com/wp-content/uploads/2021...
# 1  https://techcrunch.com/wp-content/uploads/2016...
# 2  https://cdn.cnn.com/cnnnext/dam/assets/2105181...
# 3  https://www.reuters.com/resizer/yeaYVdBQ4_EGCb...
# 4  https://s.yimg.com/os/creatr-uploaded-images/2...

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!

# Create the Bitcoin sentiment scores DataFrame
btc_sentiment_df = []
for articles in btc_headlines["articles"]:
    try:
        text = articles["content"]
        results = analyzer.polarity_scores(text)
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        btc_sentiment_df.append({
            "text": text,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
        })
    except AttributeError:
        pass
btc  = pd.DataFrame(btc_sentiment_df)
btc.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.8402       0.0    0.718     0.282
# 1    0.1280       0.0    0.957     0.043
# 2    0.0000       0.0    1.000     0.000
# 3    0.4754       0.0    0.925     0.075
# 4    0.6908       0.0    0.831     0.169
#
#                                                 text
# 0  El Salvador's President Nayib Bukele has made ...
# 1  El Salvador has become the first country in th...
# 2  Illustration by Alex Castro / The Verge\r\n\n ...
# 3  Last week, whenElon Musk tweeted that he had s...
# 4  It's all about clean energy, it seems. \r\nElo...

# %%
btc.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.102440   0.041500   0.891100   0.067350
# std     0.501026   0.053099   0.072249   0.080911
# min    -0.762700   0.000000   0.718000   0.000000
# 25%    -0.273200   0.000000   0.844000   0.000000
# 50%     0.064000   0.000000   0.899000   0.051500
# 75%     0.560725   0.072000   0.938000   0.118750
# max     0.840200   0.180000   1.000000   0.282000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_sentiment_df.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-7af055aae03b> in <module>
#       1 # Describe the Ethereum Sentiment
#       2 # YOUR CODE HERE!
# ----> 3 eth_sentiment_df.describe()
#
# AttributeError: 'list' object has no attribute 'describe'

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiment_df = []
for articles in eth_headlines["articles"]:
    try:
        text = articles["content"]
        results = analyzer.polarity_scores(text)
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        eth_sentiment_df.append({
            "text": text,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
        })
    except AttributeError:
        pass
eth  = pd.DataFrame(eth_sentiment_df)
eth.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.048620   0.050550   0.857400   0.042000
# std     0.382426   0.077423   0.220743   0.056696
# min    -0.868900   0.000000   0.000000   0.000000
# 25%    -0.345300   0.000000   0.809250   0.000000
# 50%     0.000000   0.000000   0.918500   0.000000
# 75%     0.146575   0.081750   1.000000   0.067250
# max     0.670500   0.286000   1.000000   0.188000

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiment_df = []
for articles in btc_headlines["articles"]:
    try:
        text = articles["content"]
        results = analyzer.polarity_scores(text)
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        btc_sentiment_df.append({
            "text": text,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
        })
    except AttributeError:
        pass
btc  = pd.DataFrame(btc_sentiment_df)
btc.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.142260   0.038800   0.890300   0.070900
# std     0.486007   0.053869   0.075306   0.079343
# min    -0.762700   0.000000   0.718000   0.000000
# 25%    -0.220025   0.000000   0.844000   0.000000
# 50%     0.189000   0.000000   0.893500   0.063000
# 75%     0.560725   0.075000   0.938500   0.118750
# max     0.840200   0.180000   1.000000   0.282000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()
# Create a list of stopwords
# YOUR CODE HERE!

stop = stopwords.words('english')














# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Out:
# ['cryptocurrency']

# %%
# Complete the tokenizer function
    
    
def tokenizer(text):
    """Tokenizes text."""
    # Create a list of the words
    words = word_tokenize(text)
    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    # Remove the punctuation
    words = list(filter(lambda t: t not in punctuation, words))
    # Remove the stopwords
    words = list(filter(lambda t: t.lower() not in stop, words))
    # Lemmatize Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
    return tokens

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
btc["tokens"] = btc.text.apply(tokenizer)

# %%
btc.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.8402       0.0    0.718     0.282
# 1    0.1280       0.0    0.957     0.043
# 2    0.0000       0.0    1.000     0.000
# 3    0.4754       0.0    0.925     0.075
# 4    0.6908       0.0    0.831     0.169
#
#                                                 text  \
# 0  El Salvador's President Nayib Bukele has made ...
# 1  El Salvador has become the first country in th...
# 2  Illustration by Alex Castro / The Verge\r\n\n ...
# 3  Last week, whenElon Musk tweeted that he had s...
# 4  It's all about clean energy, it seems. \r\nElo...
#
#                                               tokens
# 0  [El, Salvador, 's, President, Nayib, Bukele, m...
# 1  [El, Salvador, become, first, country, world, ...
# 2  [Illustration, Alex, Castro, Verge, Cryptocurr...
# 3  [Last, week, whenElon, Musk, tweeted, spoken, ...
# 4  ['s, clean, energy, seems, Elon, Musk, Tesla, ...

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
eth["tokens"] = eth.text.apply(tokenizer)

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
def process_text_bg(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    sw_words = [word.lower() for word in lem if word.lower() not in sw]
    bigrams = ngrams(sw_words, 2)
    output = ['_'.join(i) for i in bigrams]
    return ' '.join(output)

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
# YOUR CODE HERE!

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
# YOUR CODE HERE!

# %% [markdown]
# ---
